# %% [markdown]
# ### <b> Supervise Learning</b>

# %%
#Import library
from IPython.display import Image

# %% [markdown]
# ### K-Nearest Neighbors
#  - Basic Idea: Predict the label of data point by
#      - Looking at 'k' closest data point
#      - Taking Majority vote

# %% [markdown]
# Referrence # https://www.datacamp.com/community/tutorials/k-nearest-neighbor-classification-scikit-learn

# %%
# Load image from local storage
Image(filename = "Images/SuperviseLearning/K-NearestNeighbors.png", width = 600, height = 500)

# ![title]()

# %%
Image(filename = "Images/SuperviseLearning/k-NN.png", width = 600, height = 300)

# %% [markdown]
# ### Scikit-learn fit and Predict
#   - All machine learning models implemented as Python classes
#       - They implement algorithm for learning and predicting
#       - Store the information learned from the data
#
#   - Training a model on the data = fitting a model to data
#       - .fit() method
#   - To predict the label of new data: .predict() method

# %%
Image(filename = "Images/SuperviseLearning/FitClassifier.png", width = 600, height = 500)

# %%
Image(filename="Images/SuperviseLearning/PredictingUnlabeledData.png", width = 600, height = 500)

# ![title](Images/SuperviseLearning/FitClassifier.png)
# ![title](Images/SuperviseLearning/PredictingUnlabeledData.png)

# %% [raw]
# # Import KNeighborsClassifier from sklearn.neighbors
# from sklearn.neighbors import KNeighborsClassifier
#
# # Create arrays for the features and the response variable
# y = df['party'].values
# X = df.drop('party', axis=1).values
#
# # Create a k-NN classifier with 6 neighbors
# knn = KNeighborsClassifier(n_neighbors=6)
#
# # Fit the classifier to the data
# knn.fit(X, y)
