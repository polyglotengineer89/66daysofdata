# %% [markdown]
# # Decision tree for classification

# %% [markdown]
#  - Chapter 1: Classification and Regression Tree
#  - Chapter 2: The Bias Variant trade-off
#  - Chapter 3: Bagging and Random Forest
#  - Chapter 4: Boosting
#  - Chapter 5: Model Tuning

# %% [markdown]
# Classification Tree
#
#  - sequence of if-else question about individual features
#  - Objective: infer class label
#  - Able to capture non-linier relationship between features and label
#  - Dont required feature scaling(ex: standarization)

# %% [markdown]
# ![title](DesicionTree/breastCancer.png)
# ![title](DesicionTree/DesicionTreeDiagram.png)
# ![title](DesicionTree/classificationTree.png)
# ![title](DesicionTree/classificationTree1.png)

# %% [markdown]
# Desicion Tree Region
#  - Desicion Region:Region in feature space where all instances are assign to one class label
#  - Desicion Boundary: surface separating different desicion region
#  ![title](DesicionTree/DesicionRegion.png)
#  ![title](DesicionTree/DesicionRegion1.png)

# %%
import pandas as pd
import numpy as np


breast_cancer_data = pd.read_csv('DesicionTree/data.csv')
# breast_cancer_data.dropna(axis=1, thresh=None) 
breast_cancer_data = breast_cancer_data.dropna(axis='index', how='all') 
# breast_cancer_data['Unnamed'].isnull().sum()

# breast_cancer_data['diagnosis'] = pd.to_numeric(breast_cancer_data.diagnosis, errors='coerce')

breast_cancer_data.rename( columns={'Unnamed: 32':'Unknown_Column'}, inplace=True )
breast_cancer_data['Unknown_Column'] = breast_cancer_data['Unknown_Column'].astype(float)
breast_cancer_data = breast_cancer_data.dropna(axis=1)

breast_cancer_data['diagnosis'].replace(to_replace=['M','B'], value=[0,1],inplace=True)
breast_cancer_data.tail()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424          0        21.56         22.39          142.00     1479.0
# 565  926682          0        20.13         28.25          131.20     1261.0
# 566  926954          0        16.60         28.08          108.30      858.1
# 567  927241          0        20.60         29.33          140.10     1265.0
# 568   92751          1         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
from sklearn.model_selection import train_test_split

# Create arrays for the features and the target: X, y
X, y = breast_cancer_data.iloc[:,:-1], breast_cancer_data.iloc[:,-1]
# X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, stratify=y, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33,  random_state=42)
breast_cancer_data.dtypes
# Out:
# id                           int64
# diagnosis                    int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
# Import DecisionTreeClassifier from sklearn.tree
from sklearn.tree import DecisionTreeClassifier
# Instantiate a DecisionTreeClassifier 'dt' with a maximum depth of 6
dt = DecisionTreeClassifier(max_depth=6, random_state=1)

# Fit dt to the training set
dt.fit(X_train, y_train)

# Predict test set labels
y_pred = dt.predict(X_test)
print(y_pred[0:5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-6f651a2b31f5> in <module>
#       5
#       6 # Fit dt to the training set
# ----> 7 dt.fit(X_train, y_train)
#       8
#       9 # Predict test set labels
#
# /usr/local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# /usr/local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     189
#     190         if is_classification:
# --> 191             check_classification_targets(y)
#     192             y = np.copy(y)
#     193
#
# /usr/local/lib/python3.8/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
# ...

# %%
# Import accuracy_score
from sklearn.metrics import accuracy_score

dt = DecisionTreeClassifier(max_depth=6, random_state=1)
# Fit dt to the training set
dt.fit(X_train, y_train)

# Predict test set labels
y_pred = dt.predict(X_test)



# Compute test set accuracy  
acc = accuracy_score(y_pred, y_test)
print("Test set accuracy: {:.2f}".format(acc))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-c266d6b47754> in <module>
#       4 dt = DecisionTreeClassifier(max_depth=6, random_state=1)
#       5 # Fit dt to the training set
# ----> 6 dt.fit(X_train, y_train)
#       7
#       8 # Predict test set labels
#
# /usr/local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# /usr/local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     189
#     190         if is_classification:
# --> 191             check_classification_targets(y)
#     192             y = np.copy(y)
#     193
#
# ...

# %%
# Import LogisticRegression from sklearn.linear_model
from sklearn.linear_model import  LogisticRegression

# Instatiate logreg
logreg = LogisticRegression(random_state=1)

# Fit logreg to the training set
logreg.fit(X_train, y_train)

# Define a list called clfs containing the two classifiers logreg and dt
clfs = [logreg, dt]

# Review the decision regions of the two classifiers
plot_labeled_decision_regions(X_test, y_test, clfs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-31c30e238f95> in <module>
#       6
#       7 # Fit logreg to the training set
# ----> 8 logreg.fit(X_train, y_train)
#       9
#      10 # Define a list called clfs containing the two classifiers logreg and dt
#
# /usr/local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# -> 1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#    1349
#
# /usr/local/lib/python3.8/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
# ...

# %% [markdown]
# <b>Great work! Notice how the decision boundary produced by logistic regression is linear while the boundaries produced by the classification tree divide the feature space into rectangular regions</b>
